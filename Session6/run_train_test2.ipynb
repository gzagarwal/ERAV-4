# %% [markdown]
# # Iteration 2
# This notebook demonstrates the `train` and `test` functions for the dataset. The focus is to reduce the number of Parameters from the last iteration.

# %%
# Import required modules
import torch
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from model_2 import Net
from train import train, train_losses, train_acc
from test import test, test_losses, test_acc
from torchsummary import summary

# %%
# Data transforms (use helpers from train.py)
from train import train_transforms, test_transforms

train_transforms = train_transforms(augment=False)
test_transforms = test_transforms()

# %%
# Dataset and DataLoader
train_dataset = datasets.MNIST('./data', train=True, download=True, transform=train_transforms)
test_dataset = datasets.MNIST('./data', train=False, download=True, transform=test_transforms)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
# Model, device, optimizer
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
model = Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
summary(model, input_size=(1, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 10, 26, 26]              90
#               ReLU-2           [-1, 10, 26, 26]               0
#             Conv2d-3           [-1, 10, 24, 24]             900
#               ReLU-4           [-1, 10, 24, 24]               0
#             Conv2d-5           [-1, 20, 22, 22]           1,800
#               ReLU-6           [-1, 20, 22, 22]               0
#          MaxPool2d-7           [-1, 20, 11, 11]               0
#             Conv2d-8           [-1, 10, 11, 11]             200
#               ReLU-9           [-1, 10, 11, 11]               0
#            Conv2d-10             [-1, 10, 9, 9]             900
#              ReLU-11             [-1, 10, 9, 9]               0
#            Conv2d-12             [-1, 20, 7, 7]           1,800
#              ReLU-13             [-1, 20, 7, 7]               0
#            Conv2d-14             [-1, 10, 7, 7]             200
#              ReLU-15             [-1, 10, 7, 7]               0
#            Conv2d-16             [-1, 10, 1, 1]           4,900
# ================================================================
# Total params: 10,790
# Trainable params: 10,790
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.41
# Params size (MB): 0.04
# Estimated Total Size (MB): 0.45
# ----------------------------------------------------------------

# %%
# Training and Testing Loop
EPOCHS = 15
for epoch in range(EPOCHS):
    print(f"EPOCH: {epoch}")
    train(model, device, train_loader, optimizer, epoch)
    test(model, device, test_loader)
# Out:
# EPOCH: 0
# Loss=0.03358067199587822 Batch_id=937 Accuracy=98.58: 100%|██████████| 938/938 [00:16<00:00, 55.76it/s]
# Test set: Average loss: 0.0453, Accuracy: 9852/10000 (98.52%)
#
# EPOCH: 1
# Loss=0.009590926580131054 Batch_id=937 Accuracy=98.81: 100%|██████████| 938/938 [00:17<00:00, 53.75it/s]
# Test set: Average loss: 0.0523, Accuracy: 9825/10000 (98.25%)
#
# EPOCH: 2
# Loss=0.022102119401097298 Batch_id=937 Accuracy=98.81: 100%|██████████| 938/938 [00:16<00:00, 55.78it/s]
# Test set: Average loss: 0.0418, Accuracy: 9867/10000 (98.67%)
#
# EPOCH: 3
# Loss=0.02912173420190811 Batch_id=937 Accuracy=98.91: 100%|██████████| 938/938 [00:17<00:00, 55.02it/s]
# Test set: Average loss: 0.0432, Accuracy: 9861/10000 (98.61%)
#
# EPOCH: 4
# Loss=0.0015772682381793857 Batch_id=937 Accuracy=99.06: 100%|██████████| 938/938 [00:16<00:00, 55.60it/s]
# Test set: Average loss: 0.0378, Accuracy: 9877/10000 (98.77%)
#
# EPOCH: 5
# Loss=0.003430087585002184 Batch_id=937 Accuracy=99.06: 100%|██████████| 938/938 [00:16<00:00, 55.92it/s]
# Test set: Average loss: 0.0438, Accuracy: 9870/10000 (98.70%)
#
# EPOCH: 6
# Loss=0.08363702893257141 Batch_id=937 Accuracy=99.14: 100%|██████████| 938/938 [00:17<00:00, 53.85it/s]
# Test set: Average loss: 0.0556, Accuracy: 9821/10000 (98.21%)
#
# EPOCH: 7
# Loss=0.008434277027845383 Batch_id=937 Accuracy=99.23: 100%|██████████| 938/938 [00:16<00:00, 55.96it/s]
# Test set: Average loss: 0.0467, Accuracy: 9852/10000 (98.52%)
#
# EPOCH: 8
# Loss=0.002706581726670265 Batch_id=937 Accuracy=99.26: 100%|██████████| 938/938 [00:17<00:00, 54.38it/s]
# Test set: Average loss: 0.0410, Accuracy: 9879/10000 (98.79%)
#
# EPOCH: 9
# Loss=0.09318510442972183 Batch_id=937 Accuracy=99.29: 100%|██████████| 938/938 [00:16<00:00, 56.46it/s]
# Test set: Average loss: 0.0403, Accuracy: 9873/10000 (98.73%)
#
# EPOCH: 10
# Loss=0.03383806347846985 Batch_id=937 Accuracy=99.29: 100%|██████████| 938/938 [00:17<00:00, 55.03it/s]
# Test set: Average loss: 0.0422, Accuracy: 9874/10000 (98.74%)
#
# EPOCH: 11
# Loss=0.32865607738494873 Batch_id=937 Accuracy=99.37: 100%|██████████| 938/938 [00:16<00:00, 55.75it/s]
# Test set: Average loss: 0.0411, Accuracy: 9878/10000 (98.78%)
#
# EPOCH: 12
# Loss=0.0005998648121021688 Batch_id=937 Accuracy=99.40: 100%|██████████| 938/938 [00:16<00:00, 56.09it/s]
# Test set: Average loss: 0.0434, Accuracy: 9878/10000 (98.78%)
#
# EPOCH: 13
# Loss=0.06245098263025284 Batch_id=937 Accuracy=99.42: 100%|██████████| 938/938 [00:17<00:00, 53.65it/s]
# Test set: Average loss: 0.0484, Accuracy: 9866/10000 (98.66%)
#
# EPOCH: 14
# Loss=0.0011058039963245392 Batch_id=937 Accuracy=99.38: 100%|██████████| 938/938 [00:16<00:00, 55.82it/s]
# Test set: Average loss: 0.0704, Accuracy: 9833/10000 (98.33%)

# %%
# Plotting results
import matplotlib.pyplot as plt
fig, axs = plt.subplots(2,2,figsize=(15,10))
axs[0, 0].plot([t.item() for t in train_losses])
axs[0, 0].set_title("Training Loss")
axs[1, 0].plot(train_acc)
axs[1, 0].set_title("Training Accuracy")
axs[0, 1].plot(test_losses)
axs[0, 1].set_title("Test Loss")
axs[1, 1].plot(test_acc)
axs[1, 1].set_title("Test Accuracy")
plt.show()
